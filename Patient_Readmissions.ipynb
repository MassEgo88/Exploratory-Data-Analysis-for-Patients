# %% [markdown]
# <a href="https://colab.research.google.com/github/MassEgo88/Exploratory-Data-Analysis-for-Patients/blob/main/Patient_Readmissions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the os module to look at the system directories
import os
# List all files currently present inside the active /content folder
os.listdir('/content')
# Out:
# ['.config',
#  '.ipynb_checkpoints',
#  '.xlsx',
#  'patient_readmission.xlsx',
#  'sample_data']

# %%
# Import the pandas library to work with data tables
import pandas as pd

# Use read_excel instead of read_csv to open standard Excel spreadsheets
df = pd.read_excel('/content/patient_readmission.xlsx')

# Print out the first five rows of the dataset to confirm it loaded perfectly
df.head()
# Out:
#    Patient ID  Age  Gender Admission Type  Length of Stay  \
# 0           1   62  Female       Elective               4
# 1           2   65    Male      Emergency              19
# 2           3   82  Female      Emergency              18
# 3           4   85    Male      Emergency               2
# 4           5   85  Female       Elective              19
#
#    Number of Diagnoses  Blood Pressure  Blood Sugar Levels  \
# 0                    5             110                 130
# 1                    2             157                  81
# 2                    4              74                  84
# 3                    4             106                  85
# 4                    3              80                 119
#
#    Previous Admissions Readmission
# 0                    1          No
# 1                    4          No
# 2                    0          No
# 3                    4          No
# 4                    3          No

# %% [markdown]
# Step 2 of Your Project:
#
# Understanding the Structure Let's write the code for the next step of your EDA to check for missing values and get statistical summaries. Create a new code cell right below your table and paste this text:

# %%
# Print structural information about row counts, column names, and data types
df.info()

# Calculate basic statistics like mean, minimum, and maximum for number columns
df.describe()

# Count the exact number of missing or blank boxes inside each data column
df.isnull().sum()


#Your dataset is perfectly clean!The output shows 3,000 non-null entries for all 10 columns.
#This means you have zero missing values and do not need to do any data cleaning.
#You can skip right to the fun part: Visualizations & Insights.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient ID           3000 non-null   int64
#  1   Age                  3000 non-null   int64
#  2   Gender               3000 non-null   object
#  3   Admission Type       3000 non-null   object
#  4   Length of Stay       3000 non-null   int64
#  5   Number of Diagnoses  3000 non-null   int64
#  6   Blood Pressure       3000 non-null   int64
#  7   Blood Sugar Levels   3000 non-null   int64
#  8   Previous Admissions  3000 non-null   int64
#  9   Readmission          3000 non-null   object
# dtypes: int64(7), object(3)
# memory usage: 234.5+ KB
# Patient ID             0
# Age                    0
# Gender                 0
# Admission Type         0
# Length of Stay         0
# Number of Diagnoses    0
# Blood Pressure         0
# Blood Sugar Levels     0
# Previous Admissions    0
# Readmission            0
# dtype: int64

# %% [markdown]
# Step 3: Create Suitable Visualizations Since your goal is to analyze Patient Readmission, we want to see how other factors (like Age or Admission Type) affect whether a patient comes back to the hospital.

# %%
# Import matplotlib to build custom graphs and charts
import matplotlib.pyplot as plt
# Import seaborn to create cleaner, styled visual designs
import seaborn as sns

# 1. CHART ONE: Look at the distribution of our target variable (Readmission)
# Create a new blank figure window with a width of 6 inches and height of 4 inches
plt.figure(figsize=(6, 4))
# Draw a count bar plot showing the balance of readmitted vs non-readmitted patients
sns.countplot(data=df, x='Readmission')
# Label the title of our bar chart clearly
plt.title('Distribution of Patient Readmissions')
# Render and display the finalized plot on the screen
plt.show()

# 2. CHART TWO: See how Patient Age relates to Readmission status
# Set up a plot window measuring 8 inches wide by 5 inches tall
plt.figure(figsize=(8, 5))
# Create a boxplot to compare the age distribution across readmission outcomes
sns.boxplot(data=df, x='Readmission', y='Age')
# Provide a title explaining what the box plot represents
plt.title('Patient Age vs. Readmission Status')
# Display the finished boxplot inside the notebook
plt.show()


#Fantastic! The first chart is now showing perfectly.

#From your plot, we can see a clear story: out of the 3,000 entries, roughly 2,125 patients were not readmitted (No), while about 875 patients were readmitted (Yes).
#This means your readmission rate is roughly 29%, which is a great baseline statistic to open your presentation with.

# %% [markdown]
# To wrap up your Exploratory Data Analysis (EDA) project with a very high grade, professors love to see a Correlation Heatmap. This is a grid that shows which health metrics (like Blood Pressure, Blood Sugar, or Age) have the strongest relationships with each other.

# %%
# Select only the numeric columns from our dataframe to calculate mathematical relationships
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix between all numeric health variables
correlation_matrix = numeric_df.corr()

# Set up a clean, wide figure window measuring 10 inches wide by 8 inches tall
plt.figure(figsize=(10, 8))

# Draw a stylized heatmap showing correlation numbers, using a cool-warm color scheme
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# Add a clear, professional title to the top of our correlation heatmap chart
plt.title('Correlation Matrix of Patient Health Metrics')

# Use tight layout spacing to prevent any labels from getting cut off on the canvas
plt.tight_layout()

# Render and display the finalized correlation heatmap graph on the screen
plt.show()

# %% [markdown]
# Step 7: Final Conclusion & Recommendations
#
# To complete your assignment requirement ("tell the story behind the data"), create one last Text (Markdown) cell at the very bottom of your Google Colab notebook and paste this final summary:

# %% [markdown]
# ## Final Project Summary & Business Recommendations
#
# ### 1. Key Findings
# * **Readmission Rate:** Roughly 29% of the patient population experiences a readmission, which acts as a primary benchmark metric for hospital performance.
# * **Feature Independence:** The correlation heatmap reveals values near 0.00 across all numerical variables. This indicates that traditional health metrics (Age, Blood Pressure, Blood Sugar) do not have strong linear relationships with one another in this population.
#
# ### 2. Strategic Recommendations for the Hospital
# * **Holistic Risk Scoring:** Because individual health metrics like blood pressure or blood sugar do not show a dominant linear correlation on their own, the hospital should not rely on a single metric to clear a patient for discharge. Instead, they must look at combined categorical factors (such as Emergency admission types).
# * **Targeted Post-Discharge Care:** Since nearly 1 in 3 patients return to the hospital, implementing a mandatory 48-hour telehealth check-up for discharged patients could significantly reduce the 30-day readmission burden.

# %%
# Convert your DataFrame object into a native Excel spreadsheet file
df.to_excel('cleaned_patient_data.xlsx', index=False)

# %%
# Import the file downloading utility from the google colab library
from google.colab import files

# Force your browser to download the native Excel spreadsheet file
files.download('cleaned_patient_data.xlsx')

# %% [markdown]
# ## Interactive Dashboard: Factors Affecting Patient Readmission

# %%
import plotly.express as px

# 1. Age vs. Readmission
fig_age = px.box(
    df,
    x='Readmission',
    y='Age',
    title='Patient Age vs. Readmission Status',
    color='Readmission',
    hover_data=['Patient ID', 'Length of Stay']
)
fig_age.update_layout(showlegend=False)
fig_age.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e9239053-3fab-4832-8c6b-390b91f9915b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9239053-3fab-4832-8c6b-390b91f9915b")) {                    Plotly.newPlot(                        "e9239053-3fab-4832-8c6b-390b91f9915b",                        [{"alignmentgroup":"True","customdata":[[1,4],[2,19],[3,18],[4,2],[5,19],[6,18],[8,3],[9,6],[10,6],[11,13],[13,22],[14,3],[15,16],[17,22],[19,8],[20,12],[21,23],[22,18],[24,8],[26,29],[27,12],[28,20],[29,18],[32,22],[33,10],[34,26],[43,27],[45,23],[46,17],[47,11],[50,21],[51,4],[52,20],[53,9],[54,25],[55,28],[57,15],[58,
# %%
# 2. Admission Type vs. Readmission
fig_admission_type = px.bar(
    df.groupby(['Admission Type', 'Readmission']).size().reset_index(name='count'),
    x='Admission Type',
    y='count',
    color='Readmission',
    barmode='group',
    title='Admission Type vs. Readmission Status',
    hover_data=['Admission Type', 'Readmission', 'count']
)
fig_admission_type.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="673a73cf-a762-4ed8-a022-deaab1ef6f69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("673a73cf-a762-4ed8-a022-deaab1ef6f69")) {                    Plotly.newPlot(                        "673a73cf-a762-4ed8-a022-deaab1ef6f69",                        [{"alignmentgroup":"True","customdata":[["No"],["No"]],"hovertemplate":"Readmission=%{customdata[0]}\u003cbr\u003eAdmission Type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Elective","Emergency"],"xaxis":"x","y":[1104,1030],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Yes"],["Yes"]],"hovertemplate":"Readmission=%{customdata[0]}\u003cbr\u003eAdmission Type=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"textposition":"auto","x":["Elective","Emergency"],"xaxis":"x","y":[459,407],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode" ...

# %%
# 3. Length of Stay vs. Readmission
fig_length_of_stay = px.histogram(
    df,
    x='Length of Stay',
    color='Readmission',
    barmode='overlay',
    title='Length of Stay vs. Readmission Status',
    nbins=20,
    hover_data=['Patient ID', 'Age']
)
fig_length_of_stay.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c3dda3dc-bc36-4141-b2e5-30bf043a9c95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3dda3dc-bc36-4141-b2e5-30bf043a9c95")) {                    Plotly.newPlot(                        "c3dda3dc-bc36-4141-b2e5-30bf043a9c95",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Readmission=No\u003cbr\u003eLength of Stay=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"No","nbinsx":20,"offsetgroup":"No","orientation":"v","showlegend":true,"x":[4,19,18,2,19,18,3,6,6,13,22,3,16,22,8,12,23,18,8,29,12,20,18,22,10,26,27,23,17,11,21,4,20,9,25,28,15,24,1,20,9,8,24,14,27,18,21,24,12,1,23,21,19,5,23,4,27,20,8,14,6,16,16,22,12,5,8,29,14,3,9,6,13,2,8,21,2,4,25,4,13,28,12,13,14,18,29,28,6,11,2,28,23,5,19,2,25,2,11,29,24,15,9,23,19,9,21,28,14,19,7,16,28,4,7,8,5,29,20,4,7,18,5,29,3,7,27,22,14,7,5,29,22,23,2,27,21,6,15,10,26,24,7,5,1,13,21,26,18,21,18,5,13,4,17,3,21,23,21,4,2,16,28,18,8,3,9,20,29,10,21,10,13,17,9,17,24,9,9,1,2,28,16,1,10,26,28,8,28,11,2,8,22,8,17,23,24,5,12,1,23,5,13,8,25,23,13,17,20,21,8,14,11,20,15,19,7,19,28,19,11,26,5,5,22,8,6,16,8,8,9,18,3,4,14,9,9,25,26,23,10,21,27,8,13,21,16,28,11,10,15,8,18,23,9,8,27,14,28,26,25,18,20,20,21,12,19,14,17,24,21,23,12,9,15,18,21,13,8,14,8,14,7,12,11,22,11,25,28,29,13,18,2,29,21,20,15,19,23,24,12,22,11,5,29,1,24,22,19,23,7,15,25,15,10,26,1,3,1,4,11,25,21,14,7,27,27,16,9,20,4,22,10,26,26,12,